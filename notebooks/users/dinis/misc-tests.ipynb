# %%
#%load_ext autoreload
# %autoreload
from oss_hugo.OSS_Schedule import OSS_Schedule
from oss_hugo.API_Hugo_OSS import API_Hugo_OSS

pd.set_option('display.max_colwidth', -1)
pd.set_option('display.max_rows'    , 1000)

# %%
schedule = OSS_Schedule()
hugo     = API_Hugo_OSS()

df_sessions_participants = schedule.df_sessions_registered_participants()
df_sessions = hugo.df_sessions()
df_sessions_organizers  = df_sessions[['title','organizers']].dropna()
df_sessions_organizers['organizers_count'] = df_sessions_organizers['organizers'].apply(lambda x: len (x))

# %%
# merge both DataFrames
df_merge = df_sessions_organizers.merge(df_sessions_participants)
df_merge['total_count'] = df_merge['participants_count'] + df_merge['organizers_count']
df_merge = df_merge.sort_values(['participants_count','organizers_count'], ascending=False)

df_merge = df_merge.reset_index(drop=True)
df_merge[['title', 'total_count', 'participants_count','organizers_count','organizers','participants']]
# Out:
#                                                                 title  \
# 0   Securing the CI Pipeline
# 1   Agile Practices for Security Teams
# 2   How to scale Threat Modeling
# 3   Creating Appsec metrics and visualisation
# 4   DevSecOps Maturity Model (DSOMM)
# 5   Real world Chaos Engineering
# 6   Integrating Security Tools in the SDL
# 7   Using Wardley Maps on SOC
# 8   Application Security Verification Standard
# 9   State and future of threat modeling
# 10  Customising the Chaos Engineering Toolkit
# 11  Using graphs for GDPR mappings and visualisations
# 12  Wardley Mapping - Climatic Patterns and Using Doctrine
# 13  Zap - How to use it
# 14  Towards a unified way of describing threat models
# 15  Secrets Management
# 16  From Threat Modeling to DevSecOps metrics
# 17  Scaling API Security
# 18  Securing Kubernete's hosted APIs
# 19  Mapping boot camp
# 20  Coordinating functions within a PST organisation
# 21  Describe different ways of implementing TM in agile organisations
# 22  Writing security tests to confirm vulnerabilities and fixes
# 23  Mobile Security Testing Guide onboarding
# 24  Using Wardley Maps and Cynefin for Security
# 25  Cell based Structures for Security
# 26  OWASP Mobile Security Testing Guide 101
# 27  Lightweight privacy threat modeling using LINDDUN
# 28  Juice Shop Round Table
# 29  Juice Shop Release Night
# 30  Juice Shop Challenge Refactoring
# 31  Juice Shop Hack'n'Code
# 32  Introduction to Cynefin Framework (Training Session)
# 33  Using Cynefin Framework making strategic security decisions
# 34  Ask me anything (AMA) on GDPR
# 35  ZAP working session - automation
# 36  DevSecOps
# 37  Create a Slack bot in Python
# 38  Creating a Security Champions network
# 39  Android and iOS Security Enhancements and Crackme Apps
# 40  Mobile Basic Security Testing and Reverse Engineering
# 41  Dealing with DevSecOps Findings
# 42  Mapping OWASP DevSecOps Maturity Model to SAMMv2
# 43  Wardley Maps for Security
# 44  OWASP Application Security Curriculum Project
# 45  Mobile AppSec Verification Standard (MASVS)
# 46  OWASP SAMM
# 47  SAMM - Alignment with Threat Modeling
# 48  Juice Shop 101
# 49  Cyber Risk Modeling
# 50  Third Party Due Diligence
# 51  ZAP working session - future plans
# 52  Creating an iOS build pipeline with security checks
# 53  Share your Threat Models diagrams and create a Book
#
#     total_count  participants_count  organizers_count  \
# 0   12           11                  1
# 1   11           10                  1
# 2   9            8                   1
# 3   8            7                   1
# 4   8            7                   1
# 5   7            6                   1
# 6   7            6                   1
# 7   6            5                   1
# 8   6            5                   1
# 9   6            5                   1
# 10  5            4                   1
# 11  5            4                   1
# 12  5            4                   1
# 13  5            4                   1
# 14  5            4                   1
# 15  5            4                   1
# 16  5            4                   1
# 17  4            3                   1
# 18  4            3                   1
# 19  4            3                   1
# 20  4            3                   1
# 21  4            3                   1
# 22  4            3                   1
# 23  5            2                   3
# 24  4            2                   2
# 25  4            2                   2
# 26  4            2                   2
# 27  4            2                   2
# 28  3            2                   1
# 29  3            2                   1
# 30  3            2                   1
# 31  3            2                   1
# 32  3            2                   1
# 33  3            2                   1
# 34  3            2                   1
# 35  3            2                   1
# 36  3            2                   1
# 37  3            2                   1
# 38  3            2                   1
# 39  4            1                   3
# 40  4            1                   3
# 41  4            1                   3
# 42  4            1                   3
# 43  3            1                   2
# 44  3            1                   2
# 45  3            1                   2
# 46  3            1                   2
# 47  3            1                   2
# 48  2            1                   1
# 49  2            1                   1
# 50  2            1                   1
# 51  2            1                   1
# 52  2            1                   1
# 53  2            1                   1
#
#                                               organizers  \
# 0   [(one of participants)]
# 1   [(one of participants)]
# 2   [Steven Wierckx]
# 3   [(one of participants)]
# 4   [(one of participants)]
# 5   [(one of participants)]
# 6   [(one of participants)]
# 7   [Tony Richards]
# 8   [Jim Manico]
# 9   [Steven Wierckx]
# 10  [(one of participants)]
# 11  [(one of participants)]
# 12  [Simon Wardley]
# 13  [Simon Bennetts]
# 14  [Steven Wierckx]
# 15  [Dominik de Smit]
# 16  [(one of participants)]
# 17  [(one of participants)]
# 18  [(one of participants)]
# 19  [Simon Wardley]
# 20  [Simon Wardley]
# 21  [Steven Wierckx]
# 22  [Dinis Cruz]
# 23  [Jeroen Willemsen, Carlos Holguera, Sven Schleier]
# 24  [Simon Wardley, Dave Snowden]
# 25  [Tony Richards, Simon Wardley]
# 26  [Jeroen Willemsen, Sven Schleier]
# 27  [Steven Wierckx, Kim Wuyts]
# 28  [Bjoern Kimminich]
# 29  [Bjoern Kimminich]
# 30  [Bjoern Kimminich]
# 31  [Bjoern Kimminich]
# 32  [Dave Snowden]
# 33  [Dave Snowden]
# 34  [Tony Richards]
# 35  [Simon Bennetts]
# 36  [Dominik de Smit]
# 37  [Dinis Cruz]
# 38  [(one of participants)]
# 39  [Jeroen Willemsen, Carlos Holguera, Sven Schleier]
# 40  [Jeroen Willemsen,  Carlos Holguera,  Sven Schleier]
# 41  [Claudio Camerino, Francisco Novo, Rafael Jimenez]
# 42  [Timo Pagel, Sebastien Deleersnyder, Bart De Win]
# 43  [Mario Platt, Tony Richards]
# 44  [Adrian Winckles, John DiLeo]
# 45  [Jeroen Willemsen, Sven Schleier]
# 46  [Sebastien Deleersnyder, Bart De Win]
# 47  [Sebastien Deleersnyder, Bart De Win]
# 48  [Bjoern Kimminich]
# 49  [Phil Hugginss]
# 50  [Didar Gelici]
# 51  [Simon Bennetts]
# 52  [Sven Schleier]
# 53  [Steven Wierckx]
#
#                                                                                                                                                                                participants
# 0   [Francisco Novo, Claudio Camerino, Sven Schleier, Foteini Karantoni, Rafael Jimenez, Jean-Jacques MOIROUX, Sean Siford, Martin Rock-Evans, Dominik de Smit, Tony Richards, Andra Lezza]
# 1   [Francisco Novo, Sven Schleier, Paulino Calderon, Rafael Jimenez, Jean-Jacques MOIROUX, Jim Newman, Martin Rock-Evans, Dominik de Smit, Tony Richards, Simon Pavillon]
# 2   [Francisco Novo, Claudio Camerino, Sven Schleier, Sara Davis, Rafael Jimenez, Jim Newman, Dominik de Smit, Irene Michlin]
# 3   [Francisco Novo, Claudio Camerino, Foteini Karantoni, Rafael Jimenez, Jim Newman, Yasmin Martin, Mario Platt]
# 4   [Francisco Novo, Claudio Camerino, Rafael Jimenez, Sean Siford, Dominik de Smit, Adrian Winckles, Felipe Zipitria]
# 5   [Foteini Karantoni, Jean-Jacques MOIROUX, Sean Siford, Martin Rock-Evans, Adrian Winckles, Felipe Zipitria]
# 6   [Francisco Novo, Foteini Karantoni, Rafael Jimenez, Adrian Winckles, Felipe Zipitria, Simon Pavillon]
# 7   [Jean-Jacques MOIROUX, Jean-Jacques MOIROUX, Simon Wardley, Dinis Cruz, Phil Huggins]
# 8   [Claudio Camerino, Jean-Jacques MOIROUX, Sean Siford, Adrian Winckles, Felipe Zipitria]
# 9   [Foteini Karantoni, Jean-Jacques MOIROUX, Nick Drage, Sean Siford, Irene Michlin]
# 10  [Foteini Karantoni, Jean-Jacques MOIROUX, Sean Siford, Martin Rock-Evans]
# 11  [Jim Newman, Adrian Winckles, Didar Gelici, Yasmin Martin]
# 12  [Tony Richards, Dinis Cruz, Mario Platt, Phil Huggins]
# 13  [Francisco Novo, Claudio Camerino, Rafael Jimenez, Bjoern Kimminich]
# 14  [Foteini Karantoni, Nick Drage, Jim Newman, Sean Siford]
# 15  [Sven Schleier, Jim Newman, Sean Siford, Felipe Zipitria]
# 16  [Jim Newman, Dominik de Smit, Tony Richards, Mario Platt]
# 17  [Claudio Camerino, Jean-Jacques MOIROUX, Martin Rock-Evans]
# 18  [Francisco Novo, Rafael Jimenez, Jean-Jacques MOIROUX]
# 19  [Dinis Cruz, Mario Platt, Phil Huggins]
# 20  [Tony Richards, Tony Richards, Dinis Cruz]
# 21  [Sven Schleier, Tony Richards, Mario Platt]
# 22  [Sara Davis, Sean Siford, Bjoern Kimminich]
# 23  [Paulino Calderon, Carlos Holguera]
# 24  [Dinis Cruz, Phil Huggins]
# 25  [Jean-Jacques MOIROUX, Nick Drage]
# 26  [Paulino Calderon, Carlos Holguera]
# 27  [Jim Newman, Tony Richards]
# 28  [Jannik Hollenbach, Arpit Agrawal]
# 29  [Jannik Hollenbach, Arpit Agrawal]
# 30  [Jannik Hollenbach, Arpit Agrawal]
# 31  [Jannik Hollenbach, Arpit Agrawal]
# 32  [Nick Drage, Dinis Cruz]
# 33  [Nick Drage, Dinis Cruz]
# 34  [Tony Richards, Yasmin Martin]
# 35  [Sven Schleier, Dominik de Smit]
# 36  [Francisco Novo, Rafael Jimenez]
# 37  [Sara Davis, Felipe Zipitria]
# 38  [Claudio Camerino, Dominik de Smit]
# 39  [Paulino Calderon]
# 40  [Paulino Calderon]
# 41  [Foteini Karantoni]
# 42  [Mario Platt]
# 43  [Phil Huggins]
# 44  [Adrian Winckles]
# 45  [Paulino Calderon]
# 46  [Hardik Parekh]
# 47  [Mario Platt]
# 48  [Claudio Camerino]
# 49  [Tony Richards]
# 50  [Tony Richards]
# 51  [Bjoern Kimminich]
# 52  [Dominik de Smit]
# 53  [Yasmin Martin]

# %%
#qgrid.show_grid(df_merge)

# %%
#this code prints the name of sessions that exist in participant's schedule but don't match a session title
schedule = OSS_Schedule()
df_sessions_participants = schedule.df_sessions_registered_participants()
titles = sorted(df_sessions_participants['title'].to_list())
sessions = hugo.sessions_oss()

for title in titles:
    if sessions.get(title) is None:
        print(title)
