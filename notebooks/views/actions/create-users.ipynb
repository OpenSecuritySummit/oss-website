# %% [markdown]
# ## Create users
#
# Notebook used to create users

# %%
from oss_hugo.OSS_Participant import OSS_Participant

# %%
names = [ 'Alicia Barnes','Adrian Taylor','Ashleigh Eastway','Ashraf Aboukass',
          'Azzeddine Ramrami','Brett Crawley','Brian Johnson','Christopher Dobson',
          'Colin Lobley','Cybil Colaco','DSC-5','DSC-6','Dan Ashby','David English',
          'David Jensen','Deepak Subramanian','EJ Quinn','Emily Berman','Emma Fang',
          'Felix Kariuki','Florian Buetow','Foteini Karantoni','Gabor Pek','George Glass',
          'Harold Blankenship','Hwee Ching Neo','Jeroen Beckers','Jill McDonald','John Ellingsworth',
          'Karen Navas','Marco Mancini','Michael Duff','Mike McCamon','Mustafa Kasmani',
          'Patricia Duarte','Pedro Dantas','Peter Hicks','Pravinder Arora','Rebecca Ditchburn',
          'Robert Grace','Roberto Pérez','Roger Comastorres','Sarah Clark','Scott Hayward',
          'Simon Wardley','Steven van der Baan','William Devos','Wouter de Meijer',
          'Xavier Delgado','Yan Kravchenko','Zsolt Kalman','Zuhal Vargun']
results = []
for name in names:    
    result = OSS_Participant().create(name)
    results.append({'_status': result.get('status'), 'name': name})

pd.DataFrame(results)
# Out:
#    _status                 name
# 0    error        Alicia Barnes
# 1    error        Adrian Taylor
# 2       ok     Ashleigh Eastway
# 3       ok      Ashraf Aboukass
# 4       ok    Azzeddine Ramrami
# 5       ok        Brett Crawley
# 6       ok        Brian Johnson
# 7       ok   Christopher Dobson
# 8       ok         Colin Lobley
# 9       ok         Cybil Colaco
# 10      ok                DSC-5
# 11      ok                DSC-6
# 12      ok            Dan Ashby
# 13      ok        David English
# 14      ok         David Jensen
# 15      ok   Deepak Subramanian
# 16      ok             EJ Quinn
# 17      ok         Emily Berman
# 18      ok            Emma Fang
# 19      ok        Felix Kariuki
# 20      ok       Florian Buetow
# 21      ok    Foteini Karantoni
# 22      ok            Gabor Pek
# 23      ok         George Glass
# 24      ok   Harold Blankenship
# 25      ok       Hwee Ching Neo
# 26      ok       Jeroen Beckers
# 27      ok        Jill McDonald
# 28      ok    John Ellingsworth
# 29      ok          Karen Navas
# 30      ok        Marco Mancini
# 31      ok         Michael Duff
# 32      ok         Mike McCamon
# 33      ok      Mustafa Kasmani
# 34      ok      Patricia Duarte
# 35      ok         Pedro Dantas
# 36      ok          Peter Hicks
# 37      ok      Pravinder Arora
# 38      ok    Rebecca Ditchburn
# 39      ok         Robert Grace
# 40      ok        Roberto Pérez
# 41      ok    Roger Comastorres
# 42      ok          Sarah Clark
# 43      ok        Scott Hayward
# 44      ok        Simon Wardley
# 45      ok  Steven van der Baan
# 46      ok        William Devos
# 47      ok     Wouter de Meijer
# 48      ok       Xavier Delgado
# 49      ok       Yan Kravchenko
# 50      ok         Zsolt Kalman
# 51      ok         Zuhal Vargun
