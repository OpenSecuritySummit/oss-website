# %% [markdown]
# ## Sessions - Registered Participants
#
# These view shows the current sessions registrations

# %%
#%load_ext autoreload
# %matplotlib inline
# %autoreload
pd.set_option('display.max_colwidth', -1)
pd.set_option('display.max_rows'    , 1000)
from oss_hugo.OSS_Schedule import OSS_Schedule

# %%
schedule = OSS_Schedule()
df_sessions = schedule.df_sessions_registered_participants()

# %% [markdown]
# #### sessions with more that 3 participants

# %%
df_by_count = df_sessions[df_sessions['count']> 3]
df_by_count[['count']].sort_values(['count']).plot.barh()

# %% [markdown]
# #### all session's participant's data

# %%
#df_sessions
hugo.df_sessions()[['title','type']]
# Out:
#                                                                  title  \
# 0    None
# 1    NaN
# 2    Tracks
# 3    OWASP Juice Shop
# 4    Juice Shop Round Table
# 5    Juice Shop 101
# 6    Juice Shop Contributor Onboarding
# 7    Juice Shop Release Night
# 8    Juice Shop Challenge Refactoring
# 9    Juice Shop Hack'n'Code IV
# 10   Juice Shop Hack'n'Code I
# 11   Juice Shop Hack'n'Code II
# 12   Juice Shop Hack'n'Code III
# 13   Wardley Maps
# 14   Introduction to Wardley Maps (Training Session)
# 15   Hand's on Wardley Maps creation (Training Session)
# 16   Wardley Maps for Security
# 17   Using Wardley Maps on SOC
# 18   Mapping boot camp
# 19   Cell based Structures for Security
# 20   Coordinating functions within a PST organisation
# 21   Climatic Patterns and Using Doctrine
# 22   OWASP Projects
# 23   OWASP HoneyPot
# 24   Application Security Verification Standard
# 25   None
# 26   OWASP Application Security Curriculum Project
# 27   Education Projects
# ...
