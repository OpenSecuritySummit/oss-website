# %% [markdown]
# ## Diff of Participants between GSheet and Hugo
#
# This view shows the current diff/gaps between both data sources

# %% [markdown]
# ### Users only in GSheet

# %%
df_both = hugo.df_merged_gsheet_and_hugo_data()

def filter(row):
    return row.get('GSheet') is True and row.get('Hugo') is not True

df_both[df_both.apply(filter,axis=1)]
# Out:
# Empty DataFrame
# Columns: [Name, company, Company, Payment Status, GSheet, Hugo]
# Index: []

# %% [markdown]
# ### Users only in Hugo

# %%
df_both = hugo.df_merged_gsheet_and_hugo_data()

def filter(row):
    return row.get('GSheet') is not True and row.get('Hugo') is True

df_both[df_both.apply(filter,axis=1)]
# Out:
# Empty DataFrame
# Columns: [Name, company, Company, Payment Status, GSheet, Hugo]
# Index: []

# %% [markdown]
# ### Color code differences
# The DataFrame below marks in Red the cells that need fixing

# %%
df_both = hugo.df_merged_gsheet_and_hugo_data(True)
def compare_values(row):
    colors = ['background-color: '] * len(row)
    if not row['GSheet']:
        colors[4] = 'background-color: pink'
    if not row['Hugo']:
        colors[5] = 'background-color: pink'
    return colors

df_both.sort_values('Name').style.apply(compare_values, axis=1)._compute()
# Out:
# <style  type="text/css" >
#     #T_6fb530ee_806e_11e9_aae4_0242ac110002row0_col0 {
#             background-color:  ;
#             background-color:  ;
#         }    #T_6fb530ee_806e_11e9_aae4_0242ac110002row0_col1 {
#             background-color:  ;
#             background-color:  ;
#         }    #T_6fb530ee_806e_11e9_aae4_0242ac110002row0_col2 {
#             background-color:  ;
#             background-color:  ;
#         }    #T_6fb530ee_806e_11e9_aae4_0242ac110002row0_col3 {
#             background-color:  ;
#             background-color:  ;
#         }    #T_6fb530ee_806e_11e9_aae4_0242ac110002row0_col4 {
#             background-color:  ;
#             background-color:  ;
#         }    #T_6fb530ee_806e_11e9_aae4_0242ac110002row0_col5 {
#             background-color:  ;
#             background-color:  ;
#         }    #T_6fb530ee_806e_11e9_aae4_0242ac110002row1_col0 {
#             background-color:  ;
#             background-color:  ;
#         }    #T_6fb530ee_806e_11e9_aae4_0242ac110002row1_col1 {
#             background-color:  ;
#             background-color:  ;
#         }    #T_6fb530ee_806e_11e9_aae4_0242ac110002row1_col2 {
#             background-color:  ;
#             background-color:  ;
#         }    #T_6fb530ee_806e_11e9_aae4_0242ac110002row1_col3 {
#             background-color:  ;
#             background-color:  ;
#         }    #T_6fb530ee_806e_11e9_aae4_0242ac110002row1_col4 {
#             background-color:  ;
#             background-color:  ;
#         }    #T_6fb530ee_806e_11e9_aae4_0242ac110002row1_col5 {
#             background-color:  ;
#             background-color:  ;
#         }    #T_6fb530ee_806e_11e9_aae4_0242ac110002row2_col0 {
#             background-color:  ;
#             background-color:  ;
#         }    #T_6fb530ee_806e_11e9_aae4_0242ac110002row2_col1 {
#             background-color:  ;
#             background-color:  ;
#         }    #T_6fb530ee_806e_11e9_aae4_0242ac110002row2_col2 {
#             background-color:  ;
#             background-color:  ;
#         }    #T_6fb530ee_806e_11e9_aae4_0242ac110002row2_col3 {
#             background-color:  ;
#             background-color:  ;
#         }    #T_6fb530ee_806e_11e9_aae4_0242ac110002row2_col4 {
#             background-color:  ;
#             background-color:  ;
#         }    #T_6fb530ee_806e_11e9_aae4_0242ac110002row2_col5 {
#             background-color:  ;
#             background-color:  ;
#         }    #T_6fb530ee_806e_11e9_aae4_0242ac110002row3_col0 {
#             background-color:  ;
#             background-color:  ;
#         }    #T_6fb530ee_806e_11e9_aae4_0242ac110002row3_col1 {
#             background-color:  ;
#             background-color:  ;
#         }    #T_6fb530ee_806e_11e9_aae4_0242ac110002row3_col2 {
#             background-color:  ;
#             background-color:  ;
#         }    #T_6fb530ee_806e_11e9_aae4_0242ac110002row3_col3 {
#             background-color:  ;
#             background-color:  ;
#         }    #T_6fb530ee_806e_11e9_aae4_0242ac110002row3_col4 {
#             background-color:  ;
#             background-color:  ;
#         }    #T_6fb530ee_806e_11e9_aae4_0242ac110002row3_col5 {
#             background-color:  ;
#             background-color:  ;
#         }    #T_6fb530ee_806e_11e9_aae4_0242ac110002row4_col0 {
#             background-color:  ;
#             background-color:  ;
#         }    #T_6fb530ee_806e_11e9_aae4_0242ac110002row4_col1 {
#             background-color:  ;
#             background-color:  ;
#         }    #T_6fb530ee_806e_11e9_aae4_0242ac110002row4_col2 {
#             background-color:  ;
#             background-color:  ;
#         }    #T_6fb530ee_806e_11e9_aae4_0242ac110002row4_col3 {
#             background-color:  ;
#             background-color:  ;
#         }    #T_6fb530ee_806e_11e9_aae4_0242ac110002row4_col4 {
#             background-color:  ;
#             background-color:  ;
#         }    #T_6fb530ee_806e_11e9_aae4_0242ac110002row4_col5 {
#             background-color:  ;
#             background-color:  ;
#         }    #T_6fb530ee_806e_11e9_aae4_0242ac110002row5_col0 {
#             background-color:  ;
#             background-color:  ;
#         }    #T_6fb530ee_806e_11e9_aae4_0242ac110002row5_col1 {
#             background-color:  ;
#             background-color:  ;
#         }    #T_6fb530ee_806e_11e9_aae4_0242ac110002row5_col2 {
#             background-color:  ;
#             background-color:  ;
#         }    #T_6fb530ee_806e_11e9_aae4_0242ac110002row5_col3 {
#             background-color:  ;
#             background-color:  ;
#         }    #T_6fb530ee_806e_11e9_aae4_0242ac110002row5_col4 {
#             background-color:  ;
#             background-color:  ;
#         }    #T_6fb530ee_806e_11e9_aae4_0242ac110002row5_col5 {
#             background-color:  ;
#             background-color:  ;
#         }    #T_6fb530ee_806e_11e9_aae4_0242ac110002row6_col0 {
#             background-color:  ;
#             background-color:  ;
#         }    #T_6fb530ee_806e_11e9_aae4_0242ac110002row6_col1 {
#             background-color:  ;
#             background-color:  ;
#         }    #T_6fb530ee_806e_11e9_aae4_0242ac110002row6_col2 {
#             background-color:  ;
#             background-color:  ;
#         }    #T_6fb530ee_806e_11e9_aae4_0242ac110002row6_col3 {
#             background-color:  ;
#             background-color:  ;
#         }    #T_6fb530ee_806e_11e9_aae4_0242ac110002row6_col4 {
#             background-color:  ;
#             background-color:  ;
#         }    #T_6fb530ee_806e_11e9_aae4_0242ac110002row6_col5 {
#             background-color:  ;
#             background-color:  ;
#         }    #T_6fb530ee_806e_11e9_aae4_0242ac110002row7_col0 {
#             background-color:  ;
#             background-color:  ;
#         }    #T_6fb530ee_806e_11e9_aae4_0242ac110002row7_col1 {
#             background-color:  ;
#             background-color:  ;
#         }    #T_6fb530ee_806e_11e9_aae4_0242ac110002row7_col2 {
#             background-color:  ;
#             background-color:  ;
#         }    #T_6fb530ee_806e_11e9_aae4_0242ac110002row7_col3 {
#             background-color:  ;
#             background-color:  ;
#         }    #T_6fb530ee_806e_11e9_aae4_0242ac110002row7_col4 {
#             background-color:  ;
#             background-color:  ;
#         }    #T_6fb530ee_806e_11e9_aae4_0242ac110002row7_col5 {
#             background-color:  ;
#             background-color:  ;
#         }    #T_6fb530ee_806e_11e9_aae4_0242ac110002row8_col0 {
#             background-color:  ;
#             background-color:  ;
#         }    #T_6fb530ee_806e_11e9_aae4_0242ac110002row8_col1 {
#             background-color:  ;
#             background-color:  ;
#         }    #T_6fb530ee_806e_11e9_aae4_0242ac110002row8_col2 {
#             background-color:  ;
#             background-color:  ;
#         }    #T_6fb530ee_806e_11e9_aae4_0242ac110002row8_col3 {
#             background-color:  ;
#             background-color:  ;
#         }    #T_6fb530ee_806e_11e9_aae4_0242ac110002row8_col4 {
#             background-color:  ;
#             background-color:  ;
#         }    #T_6fb530ee_806e_11e9_aae4_0242ac110002row8_col5 {
#             background-color:  ;
#             background-color:  ;
#         }    #T_6fb530ee_806e_11e9_aae4_0242ac110002row9_col0 {
#             background-color:  ;
#             background-color:  ;
#         }    #T_6fb530ee_806e_11e9_aae4_0242ac110002row9_col1 {
#             background-color:  ;
#             background-color:  ;
#         }    #T_6fb530ee_806e_11e9_aae4_0242ac110002row9_col2 {
#             background-color:  ;
#             background-color:  ;
#         }    #T_6fb530ee_806e_11e9_aae4_0242ac110002row9_col3 {
#             background-color:  ;
#             background-color:  ;
#         }    #T_6fb530ee_806e_11e9_aae4_0242ac110002row9_col4 {
#             background-color:  ;
#             background-color:  ;
#         }    #T_6fb530ee_806e_11e9_aae4_0242ac110002row9_col5 {
#             background-color:  ;
#             background-color:  ;
#         }    #T_6fb530ee_806e_11e9_aae4_0242ac110002row10_col0 {
#             background-color:  ;
#             background-color:  ;
#         }    #T_6fb530ee_806e_11e9_aae4_0242ac110002

# %% [markdown]
# ### Explore Data (all Data)
#
# the Data Grid below is a great way to explore and filter the data

# %%
hugo.qgrid_merged_gsheet_and_hugo_data()
# Out:
# QgridWidget(grid_options={'fullWidthRows': True, 'syncColumnCellResize': True, 'forceFitColumns': True, 'defau…

# %%
|
